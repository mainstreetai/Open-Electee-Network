# %%
import os
import json
import pandas as pd
import geojson

# %%
import us
from us import states

# %%
d = '../../third_parties/elections-api/data/congress_legislators/'
state_folders = [os.path.join(d, o) for o in os.listdir(d) 
                    if os.path.isdir(os.path.join(d,o))]

# %%
congress2data = {}

for state_folder in state_folders:
    state = state_folder.split('/')[-1]
    for filename in os.listdir(state_folder):
        if filename.endswith(".json"):
            with open(os.path.join(state_folder, filename)) as f:
                data = json.load(f)
                aclu_id = data["id"]["aclu_id"]
                name = data["id"].get("ballotpedia")
                official_name = data["name"].get("official_full")
                party = data["terms"][-1]['party']
                district = str(data["terms"][-1].get('district'))
                state = data["terms"][-1]['state']
                legislator_type = data["terms"][-1].get('type')
                congress2data[aclu_id] = [aclu_id, name, official_name, party, district, state, legislator_type]

# %%
legislator_df = pd.DataFrame(congress2data.values(), columns=['aclu_id', 'name', 'official_name', 'party', 'district', 'state', 'legislator_type'])

# %%
house_legislator_df = legislator_df[legislator_df.legislator_type=='rep'].copy()

# %%
def make_code_complete(x):
    if len(x) == 1:
        return "0"+x
    else:
        return x

house_legislator_df['zeroed_district'] = house_legislator_df['district'].map(make_code_complete)

# %%
def add_state_fips(x):
    state = x['state']
    return states.__dict__[state].fips + x['zeroed_district']

house_legislator_df['congressional_district'] = house_legislator_df.apply(add_state_fips, axis=1)

# %%
house_legislator_df
# Out:
#                                           aclu_id          name  \
# 1     aclu/elections-api/congress_legislator:1012   Peter Welch
# 3     aclu/elections-api/congress_legislator:1000          None
# 4    aclu/elections-api/congress_legislator:11604          None
# 5    aclu/elections-api/congress_legislator:11607  Elaine Luria
# 6    aclu/elections-api/congress_legislator:11606          None
# ..                                            ...           ...
# 637    aclu/elections-api/congress_legislator:949          None
# 638    aclu/elections-api/congress_legislator:946          None
# 639    aclu/elections-api/congress_legislator:947          None
# 642    aclu/elections-api/congress_legislator:952          None
# 643    aclu/elections-api/congress_legislator:948    Jim Cooper
#
#                 official_name       party district state legislator_type  \
# 1                 Peter Welch    Democrat        0    VT             rep
# 3        Donald S. Beyer, Jr.    Democrat        8    VA             rep
# 4    Abigail Davis Spanberger    Democrat        7    VA             rep
# 5             Elaine G. Luria    Democrat        2    VA             rep
# 6            Denver Riggleman  Republican        5    VA             rep
# ..                        ...         ...      ...   ...             ...
# 637       John J. Duncan, Jr.  Republican        2    TN             rep
# 638              David P. Roe  Republican        1    TN             rep
# 639               Diane Black  Republican        6    TN             rep
# 642          Scott DesJarlais  Republican        4    TN             rep
# 643                Jim Cooper    Democrat        5    TN             rep
#
#     zeroed_district congressional_district
# 1                00                   5000
# 3                08                   5108
# 4                07                   5107
# 5                02                   5102
# 6                05                   5105
# ..              ...                    ...
# 637              02                   4702
# 638              01                   4701
# 639              06                   4706
# 642              04                   4704
# 643              05                   4705
#
# [533 rows x 9 columns]

# %%
with open('../../data/congress/cb_2018_us_cd116_500k.geojson') as f:
    districts = geojson.load(f)
    
geoid2dist = {}

for feat in districts['features']:
    coords = feat["geometry"]['coordinates']
    geotype = feat["geometry"]['type']
    geoid = feat['properties']['GEOID']
    geoid2dist[geoid] = feat["geometry"]

# %%
def get_dist(x):
    try:
        return geoid2dist[x]
    except:
        print(x)
        return None

house_legislator_df['geometry'] = house_legislator_df.congressional_district.apply(lambda x: get_dist(x))
# Out:
# 7800
# 6600
# 6600
# 7200
# 6900
# 1100
# 6000

# %%
house_legislator_df[house_legislator_df.geometry.notnull()]
# Out:
#                                           aclu_id          name  \
# 1     aclu/elections-api/congress_legislator:1012   Peter Welch
# 3     aclu/elections-api/congress_legislator:1000          None
# 4    aclu/elections-api/congress_legislator:11604          None
# 5    aclu/elections-api/congress_legislator:11607  Elaine Luria
# 6    aclu/elections-api/congress_legislator:11606          None
# ..                                            ...           ...
# 637    aclu/elections-api/congress_legislator:949          None
# 638    aclu/elections-api/congress_legislator:946          None
# 639    aclu/elections-api/congress_legislator:947          None
# 642    aclu/elections-api/congress_legislator:952          None
# 643    aclu/elections-api/congress_legislator:948    Jim Cooper
#
#                 official_name       party district state legislator_type  \
# 1                 Peter Welch    Democrat        0    VT             rep
# 3        Donald S. Beyer, Jr.    Democrat        8    VA             rep
# 4    Abigail Davis Spanberger    Democrat        7    VA             rep
# 5             Elaine G. Luria    Democrat        2    VA             rep
# 6            Denver Riggleman  Republican        5    VA             rep
# ..                        ...         ...      ...   ...             ...
# 637       John J. Duncan, Jr.  Republican        2    TN             rep
# 638              David P. Roe  Republican        1    TN             rep
# 639               Diane Black  Republican        6    TN             rep
# 642          Scott DesJarlais  Republican        4    TN             rep
# 643                Jim Cooper    Democrat        5    TN             rep
#
#     zeroed_district congressional_district  \
# 1                00                   5000
# 3                08                   5108
# 4                07                   5107
# 5                02                   5102
# 6                05                   5105
# ..              ...                    ...
# 637              02                   4702
# 638              01                   4701
# 639              06                   4706
# 642              04                   4704
# 643              05                   4705
#
#                                               geometry
# 1    {'type': 'Polygon', 'coordinates': [[[-73.4377...
# 3    {'type': 'Polygon', 'coordinates': [[[-77.2457...
# 4    {'type': 'Polygon', 'coordinates': [[[-78.3600...
# 5    {'type': 'MultiPolygon', 'coordinates': [[[[-7...
# 6    {'type': 'Polygon', 'coordinates': [[[-80.2319...
# ..                                                 ...
# 637  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 638  {'type': 'Polygon', 'coordinates': [[[-83.7916...
# 639  {'type': 'Polygon', 'coordinates': [[[-87.1502...
# 642  {'type': 'Polygon', 'coordinates': [[[-87.2967...
# 643  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
#
# [526 rows x 10 columns]

# %%
house_legislator_df.to_csv("../../data/congress_data.csv", index=False)
